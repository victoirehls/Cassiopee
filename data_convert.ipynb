# %%
import numpy as np

# %%
y = np.load("dice_loss/y.npy")

# %%
x = np.load("dice_loss/X.npy")

# %%
plt.imshow(x[2973])

# %%
np.unique(y[0])
# Out:
# array([0, 1], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(y[2973])

# %%
np.save('y_border_only', y)

# %%
for i in range(y.shape[0]):
    np.place(y[i],y[i]==2,0)
